# %% [markdown]
# # Experimen 4 - Implement Supervised Learning

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
salary_data=pd.read_csv("C:\\Users\\RAHUL\\OneDrive\\Desktop\\IDS_PRACTICAL\\salary_data.csv")
salary_data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
X = salary_data.iloc[:,:-1].values
print(X)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]

# %%
Y = salary_data.iloc[:, 1].values
print(Y)
# Out:
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]

# %% [markdown]
# # Linear Regression

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 1/3)
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, Y_train)
LinearRegression()
Y_Predict = lr.predict(X_test)

# %%
plt.scatter(X_train, Y_train, color='blue')
plt.plot(X_train, lr.predict(X_train), color='red')
plt.title('No of years experience ~ Salary for Training Data')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(X_test, Y_test, color='blue')
plt.plot(X_test, lr.predict(X_test), color='red')
plt.title('No of years experience ~ Salary for Training Data')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(Y_test, Y_Predict))
# Out:
# Mean Squared Error: 40712379.84960322
